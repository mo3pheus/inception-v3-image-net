# %%
from IPython.display import Image, display
import inception

# %%
inception.maybe_download()
# Out:
# Downloading Inception v3 Model ...
# Data has apparently already been downloaded and unpacked.

# %%
model = inception.Inception()

# %%
def recognition(image_path):
    display(Image(image_path))
    pred = model.classify(image_path=image_path)
    model.print_scores(pred=pred, k=10, only_first_name=True)

# %%
recognition(image_path='images/custard-apple.jpg')
# Out:
# 97.97% : custard apple
#  0.04% : artichoke
#  0.03% : strawberry
#  0.03% : passenger car
#  0.02% : jackfruit
#  0.01% : brain coral
#  0.01% : pineapple
#  0.01% : car wheel
#  0.01% : thimble
#  0.01% : sliding door

# %%
recognition(image_path='images/langur.jpg')
# Out:
# 84.60% : langur
#  2.97% : patas
#  2.33% : titi
#  1.02% : guenon
#  0.36% : squirrel monkey
#  0.35% : marmoset
#  0.30% : gibbon
#  0.28% : capuchin
#  0.21% : colobus
#  0.17% : indri

# %%
recognition(image_path='images/spoonbill.jpg')
# Out:
# 90.78% : spoonbill
#  0.07% : hummingbird
#  0.06% : flamingo
#  0.06% : bee eater
#  0.05% : dowitcher
#  0.05% : white stork
#  0.05% : thunder snake
#  0.05% : Sussex spaniel
#  0.04% : American egret
#  0.04% : black stork

# %%
recognition(image_path='images/volcano.jpg')
# Out:
# 92.83% : volcano
#  0.09% : alp
#  0.08% : fire screen
#  0.06% : matchstick
#  0.05% : promontory
#  0.04% : geyser
#  0.04% : Appenzeller
#  0.03% : missile
#  0.03% : lakeside
#  0.03% : pizza
